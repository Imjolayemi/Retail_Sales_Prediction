# %% [markdown]
# # Installing neccessary Librabry

# %%
pip install pandas numpy statsmodels scikit-learn seaborn matplotlib
# Out:
# Requirement already satisfied: pandas in .\env\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy in .\env\Lib\site-packages (2.5.0)
# Requirement already satisfied: statsmodels in .\env\Lib\site-packages (0.14.6)
# Requirement already satisfied: scikit-learn in .\env\Lib\site-packages (1.9.0)
# Requirement already satisfied: seaborn in .\env\Lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in .\env\Lib\site-packages (3.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\env\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\env\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in .\env\Lib\site-packages (from statsmodels) (1.18.0)
# Requirement already satisfied: patsy>=0.5.6 in .\env\Lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in .\env\Lib\site-packages (from statsmodels) (26.2)
# Requirement already satisfied: joblib>=1.4.0 in .\env\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in .\env\Lib\site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in .\env\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in .\env\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\env\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\env\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\env\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pillow>=9 in .\env\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in .\env\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in .\env\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# # Load Dataset and Clean

# %%
df = pd.read_csv("sales_dataset.csv")

# %%
df.head()
# Out:
#      order_id customer_id       order_date  customer_age customer_gender  \
# 0  ORD-101062   CUST-1396       2024-10-02          17.0          Female
# 1  ORD-100104   CUST-3191       2024/03/20          58.0          Female
# 2  ORD-103564   CUST-3148       2024-04-03          38.0          Female
# 3  ORD-101207   CUST-2981    July 09, 2025          44.0             NaN
# 4  ORD-103442   CUST-2252  August 12, 2024          33.0          Female
#
#   customer_segment       region    state store_type  product_category  ...  \
# 0      Home Office   South West     Ogun     Retail         groceries  ...
# 1         Consumer  South South    WARRI     Retail            Beauty  ...
# 2        Corporate   South East   Owerri  Wholesale         Furniture  ...
# 3         Consumer        North  PLATEAU     Online       Electronics  ...
# 4        Corporate   South West     OSUN     Online  Automotive Parts  ...
#
#   competitor_price economic_index season  day_of_week  is_holiday  \
# 0         25403.18          98.89  Rainy    Wednesday           N
# 1         30194.80          97.65    Dry    Wednesday       False
# 2              NaN          97.70  Rainy    Wednesday          No
# 3              NaN          93.45  Rainy    Wednesday          No
# 4         19732.94         102.91  Rainy       Monday           0
#
#    sales_rep_id sales_rep_experience_years customer_satisfaction_score  \
# 0        REP-05                       17.0                         2.8
# 1        REP-05                       11.0                         2.6
# 2        REP-33                       10.0                         5.0
# 3        REP-02                       15.0                         4.2
# 4        REP-08                       13.0                         2.5
#
#    delivery_days total_sales
# 0            6.0   184238.41
# 1            3.0   144882.33
# 2            5.0    87305.62
# 3            4.0    33005.80
# 4            5.0   108238.71
#
# [5 rows x 30 columns]

# %%
df.shape
# Out:
# (5050, 30)

# %% [markdown]
# ## Step 1 — First look at the data
#
# Before touching anything, profile it:

# %%
df.info()
df.describe(include ="all")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5050 entries, 0 to 5049
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   order_id                     5050 non-null   str
#  1   customer_id                  5050 non-null   str
#  2   order_date                   5050 non-null   str
#  3   customer_age                 4695 non-null   float64
#  4   customer_gender              4843 non-null   str
#  5   customer_segment             5050 non-null   str
#  6   region                       5050 non-null   str
#  7   state                        5050 non-null   str
#  8   store_type                   5050 non-null   str
#  9   product_category             5050 non-null   str
#  10  product_subcategory          5050 non-null   str
#  11  product_name                 5050 non-null   str
#  12  unit_price                   5050 non-null   str
#  13  quantity                     5050 non-null   int64
#  14  discount_percent             4542 non-null   float64
#  15  shipping_cost                4740 non-null   float64
#  16  payment_method               5050 non-null   str
#  17  marketing_channel            5050 non-null   str
#  18  customer_tenure_months       5050 non-null   int64
#  19  loyalty_program_member       4660 non-null   str
#  20  competitor_price             4020 non-null   float64
#  21  economic_index               5050 non-null   float64
#  22  season                       5050 non-null   str
#  23  day_of_week                  5050 non-null   str
#  24  is_holiday                   5050 non-null   str
#  25  sales_rep_id                 5050 non-null   str
#  26  sales_rep_experience_years   4902 non-null   float64
#  27  customer_satisfaction_score  4430 non-null   float64
#  28  delivery_days                4830 non-null   float64
#  29  total_sales                  5050 non-null   float64
# dtypes: float64(9), int64(2), str(19)
# memory usage: 1.2 MB
#           order_id customer_id  order_date  customer_age customer_gender  \
# count         5050        5050        5050   4695.000000            4843
# unique        5000        2284        2222           NaN               3
# top     ORD-103708   CUST-2435  2025-06-28           NaN          Female
# freq             2           8          11           NaN            2326
# mean           NaN         NaN         NaN     35.196166             NaN
# std            NaN         NaN         NaN     13.403844             NaN
# min            NaN         NaN         NaN    -18.000000             NaN
# 25%            NaN         NaN         NaN     27.000000             NaN
# 50%            NaN         NaN         NaN     35.000000             NaN
# 75%            NaN         NaN         NaN     43.000000             NaN
# max            NaN         NaN         NaN    200.000000             NaN
#
#        customer_segment         region   state store_type product_category  \
# count              5050           5050    5050       5050             5050
# unique                3              5     100          3               28
# top            Consumer  North Central  Owerri     Online        Furniture
# freq               2972           1078      85       2756              650
# mean                NaN            NaN     NaN        NaN              NaN
# std                 NaN            NaN     NaN        NaN              NaN
# min                 NaN            NaN     NaN        NaN              NaN
# 25%                 NaN            NaN     NaN        NaN              NaN
# 50%                 NaN            NaN     NaN        NaN              NaN
# 75%                 NaN            NaN     NaN        NaN              NaN
# max                 NaN            NaN     NaN        NaN              NaN
#
#         ... competitor_price economic_index season  day_of_week  is_holiday  \
# count   ...      4020.000000    5050.000000   5050         5050        5050
# unique  ...              NaN            NaN      2            7          10
# top     ...              NaN            NaN  Rainy     Thursday          no
# freq    ...              NaN            NaN   2957          758         944
# mean    ...     20550.166769      99.861792    NaN          NaN         NaN
# std     ...     12653.903935       8.013148    NaN          NaN         NaN
# min     ...       635.000000      74.000000    NaN          NaN         NaN
# 25%     ...     11189.347500      94.560000    NaN          NaN         NaN
# 50%     ...     17648.720000      99.770000    NaN          NaN         NaN
# 75%     ...     27478.567500     105.267500    NaN          NaN         NaN
# max     ...     87373.250000     127.420000    NaN          NaN         NaN
#
#         sales_rep_id sales_rep_experience_years customer_satisfaction_score  \
# count           5050                4902.000000                 4430.000000
# unique            60                        NaN                         NaN
# top           REP-30                        NaN                         NaN
# freq             102                        NaN                         NaN
# mean             NaN                   9.389841                    3.796456
# std              NaN                   5.777307                    0.922631
# min              NaN                   0.000000                   -1.000000
# 25%              NaN                   4.000000                    3.200000
# 50%              NaN                   9.000000                    3.800000
# 75%              NaN                  14.000000                    4.400000
# max              NaN                  19.000000                    7.500000
#
#         delivery_days   total_sales
# count     4830.000000  5.050000e+03
# unique            NaN           NaN
# top               NaN           NaN
# freq              NaN           NaN
# mean         5.401449  8.431377e+04
# std         11.606856  7.631097e+04
# min         -5.000000 -1.647462e+05
# 25%          4.000000  3.604373e+04
# 50%          5.000000  6.475969e+04
# 75%          6.000000  1.108492e+05
# max        365.000000  1.719890e+06
#
# [11 rows x 30 columns]

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# competitor_price               1030
# customer_satisfaction_score     620
# discount_percent                508
# loyalty_program_member          390
# customer_age                    355
# shipping_cost                   310
# delivery_days                   220
# customer_gender                 207
# sales_rep_experience_years      148
# region                            0
# customer_id                       0
# order_id                          0
# order_date                        0
# customer_segment                  0
# quantity                          0
# unit_price                        0
# product_name                      0
# product_subcategory               0
# product_category                  0
# store_type                        0
# state                             0
# marketing_channel                 0
# economic_index                    0
# customer_tenure_months            0
# payment_method                    0
# season                            0
# sales_rep_id                      0
# is_holiday                        0
# day_of_week                       0
# total_sales                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(50)

# %% [markdown]
# ### Columns that are have a missing values are:
#     competitor_price  and roughly 20.3960% is missing, which has 1030 out of 5050
#     customer_satisfaction_score  and roughly 12.2772% is missing, which has 620 out of 5050
#     discount_percent  and roughly 10.0594% is missing, which has 508 out of 5050
#     loyalty_program_member  and roughly 7.7227% is missing, which has 390 out of 5050
#     customer_age  and roughly 7.0297% is missing, which has 355 out of 5050
#     shipping_cost  and roughly 6.1386% is missing, which has 310 out of 5050
#     delivery_days  and roughly 4.3564% is missing, which has 220 out of 5050
#     customer_gender  and roughly 4.0990% is missing, which has 207 out of 5050
#     sales_rep_experience_years  and roughly 2.9306% is missing, which has 148 out of 5050
#
# ### Which columns *look* numeric but aren't (`dtype: object`):
#     No columns looks numeric
#
# ### Whether you can see duplicate rows:
#     No i cant see duplicate rows but there are actually 50 duplicated rows, when df.duplicated().sum() was run

# %% [markdown]
# ## Step 2 — Remove duplicates

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
df.shape
# Out:
# (5000, 30)

# %%
df["customer_age"].dtype
# Out:
# dtype('float64')

# %%
def clean_price(val):
    if isinstance(val, (int, float)):
        return float(val)
    val = str(val).replace("₦", "").replace(",", "").replace("NGN", "").strip()
    return float(val)

# %%
df["unit_price"] = df["unit_price"].apply(clean_price)

# %%
df["unit_price"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Step 4 — Parse `order_date` (mixed date formats)

# %%
df["order_date"] = pd.to_datetime(df["order_date"], format="mixed")

# %%
df["order_date"].dtype
# Out:
# dtype('<M8[us]')

# %%
df["order_date"]
# Out:
# 0      2024-10-02
# 1      2024-03-20
# 2      2024-04-03
# 3      2025-07-09
# 4      2024-08-12
#           ...
# 4995   2025-02-10
# 4996   2025-01-12
# 4997   2024-04-08
# 4998   2025-05-27
# 4999   2024-11-19
# Name: order_date, Length: 5000, dtype: datetime64[us]

# %% [markdown]
# ## Step 5 — Standardize messy categoricals

# %%
df.head(8)
# Out:
#      order_id customer_id order_date  customer_age customer_gender  \
# 0  ORD-101062   CUST-1396 2024-10-02          17.0          Female
# 1  ORD-100104   CUST-3191 2024-03-20          58.0          Female
# 2  ORD-103564   CUST-3148 2024-04-03          38.0          Female
# 3  ORD-101207   CUST-2981 2025-07-09          44.0             NaN
# 4  ORD-103442   CUST-2252 2024-08-12          33.0          Female
# 5  ORD-104409   CUST-1888 2024-04-07          44.0            Male
# 6  ORD-102836   CUST-3654 2024-09-10          21.0            Male
# 7  ORD-101559   CUST-3352 2024-03-17          44.0          Female
#
#   customer_segment         region    state store_type  product_category  ...  \
# 0      Home Office     South West     Ogun     Retail         groceries  ...
# 1         Consumer    South South    WARRI     Retail            Beauty  ...
# 2        Corporate     South East   Owerri  Wholesale         Furniture  ...
# 3         Consumer          North  PLATEAU     Online       Electronics  ...
# 4        Corporate     South West     OSUN     Online  Automotive Parts  ...
# 5      Home Office  North Central   Ilorin     Retail         FURNITURE  ...
# 6         Consumer          North     Kano     Retail       Electronics  ...
# 7      Home Office     South West    lagos     Online          Clothing  ...
#
#   competitor_price economic_index  season  day_of_week  is_holiday  \
# 0         25403.18          98.89   Rainy    Wednesday           N
# 1         30194.80          97.65     Dry    Wednesday       False
# 2              NaN          97.70   Rainy    Wednesday          No
# 3              NaN          93.45   Rainy    Wednesday          No
# 4         19732.94         102.91   Rainy       Monday           0
# 5          4147.65         104.26   Rainy       Sunday          No
# 6         29418.42          92.45   Rainy    Wednesday          no
# 7         38670.43         102.69     Dry       Sunday          No
#
#    sales_rep_id sales_rep_experience_years customer_satisfaction_score  \
# 0        REP-05                       17.0                         2.8
# 1        REP-05                       11.0                         2.6
# 2        REP-33                       10.0                         5.0
# 3        REP-02                       15.0                         4.2
# 4        REP-08                       13.0                         2.5
# 5        REP-34                        3.0                         4.4
# 6        REP-32                       15.0                         3.0
# 7        REP-02                        6.0                         4.1
#
#    delivery_days total_sales
# 0            6.0   184238.41
# 1            3.0   144882.33
# 2            5.0    87305.62
# 3            4.0    33005.80
# 4            5.0   108238.71
# 5            9.0    -6005.57
# 6            3.0    51558.21
# 7            6.0   139252.63
#
# [8 rows x 30 columns]

# %%
text_cols = ["state", "product_category", "payment_method", "region",
             "customer_segment", "store_type", "marketing_channel"]

for col in text_cols:
    df[col] = (
        df[col]
        .astype(str)
        .str.strip()
        .str.replace("_", "")
        .str.title()
    )

# %%
df["state"].unique
# Out:
# <bound method Series.unique of 0          Ogun
# 1         Warri
# 2        Owerri
# 3       Plateau
# 4          Osun
#          ...
# 4995    Onitsha
# 4996     Ilorin
# 4997      Abuja
# 4998     Ilorin
# 4999        Jos
# Name: state, Length: 5000, dtype: str>

# %%
df["product_category"].unique
# Out:
# <bound method Series.unique of 0              Groceries
# 1                 Beauty
# 2              Furniture
# 3            Electronics
# 4       Automotive Parts
#               ...
# 4995    Automotive Parts
# 4996         Electronics
# 4997         Electronics
# 4998     Office Supplies
# 4999         Electronics
# Name: product_category, Length: 5000, dtype: str>

# %%
df["payment_method"].unique
# Out:
# <bound method Series.unique of 0       Bank Transfer
# 1          Debit Card
# 2                Ussd
# 3                Ussd
# 4                Ussd
#             ...
# 4995     Mobile Money
# 4996      Credit Card
# 4997      Credit Card
# 4998       Debit Card
# 4999       Creditcard
# Name: payment_method, Length: 5000, dtype: str>

# %%
df["state"].nunique()
# Out:
# 25

# %% [markdown]
# ## Step 6 — Standardize boolean columns

# %%
df["loyalty_program_member"]
# Out:
# 0           N
# 1         NaN
# 2         NaN
# 3         Yes
# 4         NaN
#         ...
# 4995      yes
# 4996    False
# 4997      NaN
# 4998    False
# 4999        Y
# Name: loyalty_program_member, Length: 5000, dtype: str

# %%
df["is_holiday"]
# Out:
# 0           N
# 1       False
# 2          No
# 3          No
# 4           0
#         ...
# 4995        0
# 4996       no
# 4997      yes
# 4998    False
# 4999    False
# Name: is_holiday, Length: 5000, dtype: str

# %%
true_values = {"yes", "y", "1", "true"}

def to_bool(val):
    if pd.isna(val):
        return np.nan
    return str(val).strip().lower() in true_values

# %%
df["loyalty_program_member"] = df["loyalty_program_member"].apply(to_bool)

# %%
df["is_holiday"] = df["is_holiday"].apply(to_bool)

# %%
df["is_holiday"].dtype
# Out:
# dtype('bool')

# %%
df["loyalty_program_member"].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## Step 7 — Handle invalid / impossible values

# %%
df.loc[(df["customer_age"] < 0) | (df["customer_age"] > 100), "customer_age"] = np.nan
df.loc[(df["quantity"] <= 0), "quantity"] = np.nan
df["discount_percent"] = df["discount_percent"].clip(0, 100)
df["customer_satisfaction_score"] = df["customer_satisfaction_score"].clip(1, 5)
df.loc[(df["delivery_days"] < 0) | (df["delivery_days"] > 60), "delivery_days"] = np.nan
df = df[df["total_sales"] >= 0]

# %%
df.shape
# Out:
# (4995, 30)

# %% [markdown]
# ## Step 8 — Decide on rare, extreme `total_sales` outliers

# %%
df["total_sales"].describe
# Out:
# <bound method NDFrame.describe of 0       184238.41
# 1       144882.33
# 2        87305.62
# 3        33005.80
# 4       108238.71
#           ...
# 4995     30747.10
# 4996    137752.31
# 4997    144595.85
# 4998     18476.81
# 4999     35370.86
# Name: total_sales, Length: 4995, dtype: float64>

# %%
sns.boxplot(x=df["total_sales"])
# Out:
# <Axes: xlabel='total_sales'>

# %%
cap = df["total_sales"].quantile(0.99)

# %%
 df["total_sales"] =  df["total_sales"].clip(upper=cap)

# %%
The **Cap (winsorize)** at the 99th percentile was chosen because since we are dealing with sales and the outliers really fall in the category of others
